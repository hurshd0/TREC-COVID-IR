# %%
# %reload_ext memory_profiler

import warnings
warnings.filterwarnings(action='ignore')

# ----------------- Classics -------------------- #
import numpy as np
import pandas as pd

# ---------------- Pandas settings --------------- #
# Removes rows and columns truncation of '...'
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# ------------------- Python libs ---------------- #
import os, sys, re
import pprint
pp = pprint.PrettyPrinter(indent=4)
from pathlib import Path
ROOT_PATH = Path().resolve().parent
sys.path.append(str(ROOT_PATH)) # Add folder root path

import typing as t
import timeit

from tqdm import tqdm
tqdm.pandas()

# ------------------- NLP libs ---------------------- #
from utils.tokenizer import Tokenizer

# %% [markdown]
# We know adding `query+question` improves the baseline TF-IDF model, so let's now improve the Query by only identifying key entities from `question` and including those, but first let's understand some term frequency in query, how stopwords affects it and how using SciSpacy we can improve query and maybe do query expansion.

# %% [markdown]
# # 1. Load topics

# %%
def load_queries(input_fpath: Path, dtype: str = 'csv', cols_to_keep=['topic-id', 'query', 'question'], index_col=['topic-id']) -> pd.DataFrame:
    """Loads queries file and returns it as pandas data frame
    """
    if dtype == 'csv':
        df = pd.read_csv(input_fpath, quotechar='"', index_col=index_col, usecols=cols_to_keep)
        # for each column
        for col in df.columns:
            # check if the columns contains string data
            if pd.api.types.is_string_dtype(df[col]):
                df[col] = df[col].str.strip() # removes front and end white spaces
                df[col] = df[col].str.replace('\s{2,}', ' ') # remove double or more white spaces
    return df

QUERY_FPATH = Path('../data/CORD-19/CORD-19/topics-rnd3.csv')
query_df = load_queries(QUERY_FPATH)
query_df['query+question'] = query_df['query'] + ' ' + query_df['question']
query_df.head()
# Out:
#                                             query  \
# topic-id
# 1                              coronavirus origin
# 2         coronavirus response to weather changes
# 3                            coronavirus immunity
# 4          how do people die from the coronavirus
# 5                       animal models of COVID-19
#
#                                                    question  \
# topic-id
# 1                            what is the origin of COVID-19
# 2         how does the coronavirus respond to changes in...
# 3         will SARS-CoV2 infected people develop immunit...
# 4                          what causes death from Covid-19?
# 5         what drugs have been active against SARS-CoV o...
#
#                                              query+question
# topic-id
# 1         coronavirus origin what is the origin of COVID-19
# 2         coronavirus response to weather changes how do...
# 3         coronavirus immunity will SARS-CoV2 infected p...
# 4         how do people die from the coronavirus what ca...
# 5         animal models of COVID-19 what drugs have been...

# %% [markdown]
# ### Effects of Stopwords removal and using SciSpacy pre_processing

# %%
# 1. Init tokenizer with:
tk_nltk_stop = Tokenizer('l-s') # lowercase + stopwords
punct_nltk_stop = Tokenizer('l-s-pt') # lowercase + stopwords + punctuation
lem_nltk_stop = Tokenizer('l-s-pt-lm') # lowercase + stopwords + punctuation + lemmatizing

# %%
# 2. Init custom stopwords tokenizer
tk_cus_stop = Tokenizer('l-s-lm-pt')
custom_stopwords_path = ROOT_PATH / 'utils/stopwords.txt'
tk_cus_stop.load_stop_words(custom_stopwords_path, combine_w_nltk=True)
# Out:
# 	Custom STOPWORDS loaded successfully !(^^)!

# %%
# 3. Load Scispacy model
import spacy
nlp = spacy.load('en_core_sci_md')

# %%
for topic_id, row in query_df.iterrows():
    topic = row['query']
    question = row['question']
    print(f"{topic_id}")
    print(f"\t[BASE]: {topic}, {question}")
    nltk_topic = ' '.join(tk_nltk_stop.tokenize(topic))
    nltk_question = ' '.join(tk_nltk_stop.tokenize(question))
    print(f"\t[NLTK low + stop]: {nltk_topic}, {nltk_question}")
    nltk_topic = ' '.join(punct_nltk_stop.tokenize(topic))
    nltk_question = ' '.join(punct_nltk_stop.tokenize(question))
    print(f"\t[NLTK low + stop + punct]: {nltk_topic}, {nltk_question}")
    nltk_topic = ' '.join(lem_nltk_stop.tokenize(topic))
    nltk_question = ' '.join(lem_nltk_stop.tokenize(question))
    print(f"\t[NLTK low + stop + punct + lemma]: {nltk_topic}, {nltk_question}")
    cus_topic = ' '.join(tk_cus_stop.tokenize(topic))
    cus_question = ' '.join(tk_cus_stop.tokenize(question))
    print(f"\t[CUSTOM STOPWORDS]: {cus_topic}, {cus_question}")
    doc = nlp(question)
    ents = [{e.label_:e.text} for e in doc.ents]
    print(f"\t[NER]: {ents}")
# Out:
# 1
# 	[BASE]: coronavirus origin, what is the origin of COVID-19
# 	[NLTK low + stop]: coronavirus origin, origin covid-19
# 	[NLTK low + stop + punct]: coronavirus origin, origin covid-19
# 	[NLTK low + stop + punct + lemma]: coronavirus origin, origin covid-19
# 	[CUSTOM STOPWORDS]: coronavirus origin, origin covid-19
# 	[NER]: [{'ENTITY': 'origin'}, {'ENTITY': 'COVID-19'}]
# 2
# 	[BASE]: coronavirus response to weather changes, how does the coronavirus respond to changes in the weather
# 	[NLTK low + stop]: coronavirus response weather changes, coronavirus respond changes weather
# 	[NLTK low + stop + punct]: coronavirus response weather changes, coronavirus respond changes weather
# 	[NLTK low + stop + punct + lemma]: coronavirus response weather change, coronavirus respond change weather
# 	[CUSTOM STOPWORDS]: coronavirus response weather change, coronavirus respond change weather
# 	[NER]: [{'ENTITY': 'coronavirus'}, {'ENTITY': 'changes'}, {'ENTITY': 'weather'}]
# 3
# 	[BASE]: coronavirus immunity, will SARS-CoV2 infected people develop immunity? Is cross protection possible?
# 	[NLTK low + stop]: coronavirus immunity, sars-cov2 infected people develop immunity ? cross protection possible ?
# 	[NLTK low + stop + punct]: coronavirus immunity, sars-cov2 infected people develop immunity cross protection possible
# 	[NLTK low + stop + punct + lemma]: coronavirus immunity, sars-cov2 infected people develop immunity cross protection possible
# 	[CUSTOM STOPWORDS]: coronavirus immunity, sars-cov2 infected people develop immunity cross protection possible
# 	[NER]: [{'ENTITY': 'SARS-CoV2'}, {'ENTITY': 'infected'}, {'ENTITY': 'people'}, {'ENTITY': 'immunity'}, {'ENTITY': 'cross protection'}]
# 4
# 	[BASE]: how do people die from the coronavirus, what causes death from Covid-19?
# 	[NLTK low + stop]: people die coronavirus, causes death covid-19 ?
# 	[NLTK low + stop + punct]: people die coronavirus, causes death covid-19
# 	[NLTK low + stop + punct + lemma]: people die coronavirus, cause death covid-19
# 	[CUSTOM STOPWORDS]: people die coronavirus, cause death covid-19
# 	[NER]: [{'ENTITY': 'causes'}, {'ENTITY': 'death'}, {'ENTITY': 'Covid-19'}]
# 5
# 	[BASE]: animal models of COVID-19, what drugs have been active against SARS-CoV or SARS-CoV-2 in animal studies?
# 	[NLTK low + stop]: animal models covid-19, drugs active sars-cov sars-cov-2 animal studies ?
# 	[NLTK low + stop + punct]: animal models covid-19, drugs active sars-cov sars-cov-2 animal studies
# 	[NLTK low + stop + punct + lemma]: animal model covid-19, drug active sars-cov sars-cov-2 animal study
# 	[CUSTOM STOPWORDS]: animal model covid-19, drug active sars-cov sars-cov-2 animal study
# 	[NER]: [{'ENTITY': 'drugs'}, {'ENTITY': 'active'}, {'ENTITY': 'SARS-CoV'}, {'ENTITY': 'SARS-CoV-2'}, {'ENTITY': 'animal studies'}]
# 6
# 	[BASE]: coronavirus test rapid testing, what types of rapid testing for Covid-19 have been developed?
# 	[NLTK low + stop]: coronavirus test rapid testing, types rapid testing covid-19 developed ?
# 	[NLTK low + stop + punct]: coronavirus test rapid testing, types rapid testing covid-19 developed
# 	[NLTK low + stop + punct + lemma]: coronavirus test rapid test, type rapid test covid-19 develop
# 	[CUSTOM STOPWORDS]: coronavirus test rapid test, type rapid test covid-19 develop
# 	[NER]: [{'ENTITY': 'rapid testing'}, {'ENTITY': 'Covid-19'}]
# 7
# 	[BASE]: serological tests for coronavirus, are there serological tests that detect antibodies to coronavirus?
# 	[NLTK low + stop]: serological tests coronavirus, serological tests detect antibodies coronavirus ?
# 	[NLTK low + stop + punct]: serological tests coronavirus, serological tests detect antibodies coronavirus
# 	[NLTK low + stop + punct + lemma]: serological test coronavirus, serological test detect antibody coronavirus
# 	[CUSTOM STOPWORDS]: serological test coronavirus, serological test detect antibody coronavirus
# 	[NER]: [{'ENTITY': 'serological tests'}, {'ENTITY': 'detect'}, {'ENTITY': 'antibodies'}, {'ENTITY': 'coronavirus'}]
# 8
# 	[BASE]: coronavirus under reporting, how has lack of testing availability led to underreporting of true incidence of Covid-19?
# 	[NLTK low + stop]: coronavirus reporting, lack testing availability led underreporting true incidence covid-19 ?
# 	[NLTK low + stop + punct]: coronavirus reporting, lack testing availability led underreporting true incidence covid-19
# 	[NLTK low + stop + punct + lemma]: coronavirus reporting, lack test availability lead underreporting true incidence covid-19
# 	[CUSTOM STOPWORDS]: coronavirus reporting, lack test availability lead underreporting true incidence covid-19
# 	[NER]: [{'ENTITY': 'lack'}, {'ENTITY': 'testing'}, {'ENTITY': 'availability'}, {'ENTITY': 'underreporting'}, {'ENTITY': 'incidence'}, {'ENTITY': 'Covid-19'}]
# 9
# 	[BASE]: coronavirus in Canada, how has COVID-19 affected Canada
# 	[NLTK low + stop]: coronavirus canada, covid-19 affected canada
# 	[NLTK low + stop + punct]: coronavirus canada, covid-19 affected canada
# 	[NLTK low + stop + punct + lemma]: coronavirus canada, covid-19 affect canada
# 	[CUSTOM STOPWORDS]: coronavirus canada, covid-19 affect canada
# 	[NER]: [{'ENTITY': 'COVID-19'}, {'ENTITY': 'affected'}, {'ENTITY': 'Canada'}]
# 10
# 	[BASE]: coronavirus social distancing impact, has social distancing had an impact on slowing the spread of COVID-19?
# 	[NLTK low + stop]: coronavirus social distancing impact, social distancing impact slowing spread covid-19 ?
# 	[NLTK low + stop + punct]: coronavirus social distancing impact, social distancing impact slowing spread covid-19
# 	[NLTK low + stop + punct + lemma]: coronavirus social distancing impact, social distance impact slow spread covid-19
# 	[CUSTOM STOPWORDS]: coronavirus social distancing impact, social distance impact slow spread covid-19
# 	[NER]: [{'ENTITY': 'social distancing'}, {'ENTITY': 'impact'}, {'ENTITY': 'spread'}, {'ENTITY': 'COVID-19'}]
# 11
# 	[BASE]: coronavirus hospital rationing, what are the guidelines for triaging patients infected with coronavirus?
# 	[NLTK low + stop]: coronavirus hospital rationing, guidelines triaging patients infected coronavirus ?
# 	[NLTK low + stop + punct]: coronavirus hospital rationing, guidelines triaging patients infected coronavirus
# 	[NLTK low + stop + punct + lemma]: coronavirus hospital rationing, guideline triaging patient infect coronavirus
# 	[CUSTOM STOPWORDS]: coronavirus hospital rationing, guideline triaging patient infect coronavirus
# 	[NER]: [{'ENTITY': 'guidelines'}, {'ENTITY': 'triaging'}, {'ENTITY': 'patients'}, {'ENTITY': 'infected'}, {'ENTITY': 'coronavirus'}]
# 12
# 	[BASE]: coronavirus quarantine, what are best practices in hospitals and at home in maintaining quarantine?
# 	[NLTK low + stop]: coronavirus quarantine, best practices hospitals home maintaining quarantine ?
# 	[NLTK low + stop + punct]: coronavirus quarantine, best practices hospitals home maintaining quarantine
# 	[NLTK low + stop + punct + lemma]: coronavirus quarantine, best practice hospital home maintain quarantine
# 	[CUSTOM STOPWORDS]: coronavirus quarantine, best practice hospital home maintain quarantine
# 	[NER]: [{'ENTITY': 'practices'}, {'ENTITY': 'hospitals'}, {'ENTITY': 'home'}, {'ENTITY': 'quarantine'}]
# 13
# 	[BASE]: how does coronavirus spread, what are the transmission routes of coronavirus?
# 	[NLTK low + stop]: coronavirus spread, transmission routes coronavirus ?
# 	[NLTK low + stop + punct]: coronavirus spread, transmission routes coronavirus
# 	[NLTK low + stop + punct + lemma]: coronavirus spread, transmission route coronavirus
# 	[CUSTOM STOPWORDS]: coronavirus spread, transmission route coronavirus
# 	[NER]: [{'ENTITY': 'transmission'}, {'ENTITY': 'routes'}, {'ENTITY': 'coronavirus'}]
# 14
# 	[BASE]: coronavirus super spreaders, what evidence is there related to COVID-19 super spreaders
# 	[NLTK low + stop]: coronavirus super spreaders, evidence related covid-19 super spreaders
# 	[NLTK low + stop + punct]: coronavirus super spreaders, evidence related covid-19 super spreaders
# 	[NLTK low + stop + punct + lemma]: coronavirus super spreader, evidence relate covid-19 super spreader
# 	[CUSTOM STOPWORDS]: coronavirus super spreader, evidence relate covid-19 super spreader
# 	[NER]: [{'ENTITY': 'evidence'}, {'ENTITY': 'COVID-19'}]
# 15
# 	[BASE]: coronavirus outside body, how long can the coronavirus live outside the body
# 	[NLTK low + stop]: coronavirus outside body, long coronavirus live outside body
# 	[NLTK low + stop + punct]: coronavirus outside body, long coronavirus live outside body
# 	[NLTK low + stop + punct + lemma]: coronavirus outside body, long coronavirus live outside body
# 	[CUSTOM STOPWORDS]: coronavirus body, long coronavirus live body
# 	[NER]: [{'ENTITY': 'coronavirus'}, {'ENTITY': 'live'}, {'ENTITY': 'body'}]
# 16
# 	[BASE]: how long does coronavirus survive on surfaces, how long does coronavirus remain stable on surfaces?
# 	[NLTK low + stop]: long coronavirus survive surfaces, long coronavirus remain stable surfaces ?
# 	[NLTK low + stop + punct]: long coronavirus survive surfaces, long coronavirus remain stable surfaces
# 	[NLTK low + stop + punct + lemma]: long coronavirus survive surface, long coronavirus remain stable surface
# 	[CUSTOM STOPWORDS]: long coronavirus survive surface, long coronavirus remain stable surface
# 	[NER]: [{'ENTITY': 'long'}, {'ENTITY': 'coronavirus'}, {'ENTITY': 'stable'}, {'ENTITY': 'surfaces'}]
# 17
# 	[BASE]: coronavirus clinical trials, are there any clinical trials available for the coronavirus
# 	[NLTK low + stop]: coronavirus clinical trials, clinical trials available coronavirus
# 	[NLTK low + stop + punct]: coronavirus clinical trials, clinical trials available coronavirus
# 	[NLTK low + stop + punct + lemma]: coronavirus clinical trial, clinical trial available coronavirus
# 	[CUSTOM STOPWORDS]: coronavirus clinical trial, clinical trial available coronavirus
# 	[NER]: [{'ENTITY': 'clinical trials'}, {'ENTITY': 'coronavirus'}]
# 18
# 	[BASE]: masks prevent coronavirus, what are the best masks for preventing infection by Covid-19?
# 	[NLTK low + stop]: masks prevent coronavirus, best masks preventing infection covid-19 ?
# 	[NLTK low + stop + punct]: masks prevent coronavirus, best masks preventing infection covid-19
# 	[NLTK low + stop + punct + lemma]: mask prevent coronavirus, best mask prevent infection covid-19
# 	[CUSTOM STOPWORDS]: mask prevent coronavirus, best mask prevent infection covid-19
# 	[NER]: [{'ENTITY': 'masks'}, {'ENTITY': 'preventing'}, {'ENTITY': 'infection'}, {'ENTITY': 'Covid-19'}]
# 19
# 	[BASE]: what alcohol sanitizer kills coronavirus, what type of hand sanitizer is needed to destroy Covid-19?
# 	[NLTK low + stop]: alcohol sanitizer kills coronavirus, type hand sanitizer needed destroy covid-19 ?
# 	[NLTK low + stop + punct]: alcohol sanitizer kills coronavirus, type hand sanitizer needed destroy covid-19
# 	[NLTK low + stop + punct + lemma]: alcohol sanitizer kill coronavirus, type hand sanitizer need destroy covid-19
# 	[CUSTOM STOPWORDS]: alcohol sanitizer kill coronavirus, type hand sanitizer need destroy covid-19
# 	[NER]: [{'ENTITY': 'hand sanitizer'}, {'ENTITY': 'destroy'}, {'ENTITY': 'Covid-19'}]
# 20
# 	[BASE]: coronavirus and ACE inhibitors, are patients taking Angiotensin-converting enzyme inhibitors (ACE) at increased risk for COVID-19?
# 	[NLTK low + stop]: coronavirus ace inhibitors, patients taking angiotensin-converting enzyme inhibitors ( ace ) increased risk covid-19 ?
# 	[NLTK low + stop + punct]: coronavirus ace inhibitors, patients taking angiotensin-converting enzyme inhibitors ace increased risk covid-19
# 	[NLTK low + stop + punct + lemma]: coronavirus ace inhibitor, patient take angiotensin-converting enzyme inhibitor ace increase risk covid-19
# 	[CUSTOM STOPWORDS]: coronavirus ace inhibitor, patient take angiotensin-converting enzyme inhibitor ace increase risk covid-19
# 	[NER]: [{'ENTITY': 'patients'}, {'ENTITY': 'Angiotensin-converting enzyme inhibitors'}, {'ENTITY': 'ACE'}, {'ENTITY': 'increased'}, {'ENTITY': 'risk'}, {'ENTITY': 'COVID-19'}]
# 21
# 	[BASE]: coronavirus mortality, what are the mortality rates overall and in specific populations
# 	[NLTK low + stop]: coronavirus mortality, mortality rates overall specific populations
# 	[NLTK low + stop + punct]: coronavirus mortality, mortality rates overall specific populations
# 	[NLTK low + stop + punct + lemma]: coronavirus mortality, mortality rate overall specific population
# 	[CUSTOM STOPWORDS]: coronavirus mortality, mortality rate overall specific population
# 	[NER]: [{'ENTITY': 'mortality'}, {'ENTITY': 'rates'}, {'ENTITY': 'specific'}, {'ENTITY': 'populations'}]
# 22
# 	[BASE]: coronavirus heart impacts, are cardiac complications likely in patients with COVID-19?
# 	[NLTK low + stop]: coronavirus heart impacts, cardiac complications likely patients covid-19 ?
# 	[NLTK low + stop + punct]: coronavirus heart impacts, cardiac complications likely patients covid-19
# 	[NLTK low + stop + punct + lemma]: coronavirus heart impact, cardiac complication likely patient covid-19
# 	[CUSTOM STOPWORDS]: coronavirus heart impact, cardiac complication likely patient covid-19
# 	[NER]: [{'ENTITY': 'cardiac complications'}, {'ENTITY': 'patients'}, {'ENTITY': 'COVID-19'}]
# 23
# 	[BASE]: coronavirus hypertension, what kinds of complications related to COVID-19 are associated with hypertension?
# 	[NLTK low + stop]: coronavirus hypertension, kinds complications related covid-19 associated hypertension ?
# 	[NLTK low + stop + punct]: coronavirus hypertension, kinds complications related covid-19 associated hypertension
# 	[NLTK low + stop + punct + lemma]: coronavirus hypertension, kind complication related covid-19 associate hypertension
# 	[CUSTOM STOPWORDS]: coronavirus hypertension, kind complication related covid-19 associate hypertension
# 	[NER]: [{'ENTITY': 'complications'}, {'ENTITY': 'COVID-19'}, {'ENTITY': 'associated with'}, {'ENTITY': 'hypertension'}]
# 24
# 	[BASE]: coronavirus diabetes, what kinds of complications related to COVID-19 are associated with diabetes
# 	[NLTK low + stop]: coronavirus diabetes, kinds complications related covid-19 associated diabetes
# 	[NLTK low + stop + punct]: coronavirus diabetes, kinds complications related covid-19 associated diabetes
# 	[NLTK low + stop + punct + lemma]: coronavirus diabetes, kind complication related covid-19 associate diabetes
# 	[CUSTOM STOPWORDS]: coronavirus diabetes, kind complication related covid-19 associate diabetes
# 	[NER]: [{'ENTITY': 'complications'}, {'ENTITY': 'COVID-19'}, {'ENTITY': 'associated with'}, {'ENTITY': 'diabetes'}]
# 25
# 	[BASE]: coronavirus biomarkers, which biomarkers predict the severe clinical course of 2019-nCOV infection?
# 	[NLTK low + stop]: coronavirus biomarkers, biomarkers predict severe clinical course 2019-ncov infection ?
# 	[NLTK low + stop + punct]: coronavirus biomarkers, biomarkers predict severe clinical course 2019-ncov infection
# 	[NLTK low + stop + punct + lemma]: coronavirus biomarkers, biomarkers predict severe clinical course 2019-ncov infection
# 	[CUSTOM STOPWORDS]: coronavirus biomarkers, biomarkers predict severe clinical course 2019-ncov infection
# 	[NER]: [{'ENTITY': 'biomarkers'}, {'ENTITY': 'severe'}, {'ENTITY': 'clinical course'}, {'ENTITY': 'infection'}]
# 26
# 	[BASE]: coronavirus early symptoms, what are the initial symptoms of Covid-19?
# 	[NLTK low + stop]: coronavirus early symptoms, initial symptoms covid-19 ?
# 	[NLTK low + stop + punct]: coronavirus early symptoms, initial symptoms covid-19
# 	[NLTK low + stop + punct + lemma]: coronavirus early symptom, initial symptom covid-19
# 	[CUSTOM STOPWORDS]: coronavirus early symptom, initial symptom covid-19
# 	[NER]: [{'ENTITY': 'initial'}, {'ENTITY': 'symptoms'}, {'ENTITY': 'Covid-19'}]
# 27
# 	[BASE]: coronavirus asymptomatic, what is known about those infected with Covid-19 but are asymptomatic?
# 	[NLTK low + stop]: coronavirus asymptomatic, known infected covid-19 asymptomatic ?
# 	[NLTK low + stop + punct]: coronavirus asymptomatic, known infected covid-19 asymptomatic
# 	[NLTK low + stop + punct + lemma]: coronavirus asymptomatic, know infected covid-19 asymptomatic
# 	[CUSTOM STOPWORDS]: coronavirus asymptomatic, know infected covid-19 asymptomatic
# 	[NER]: [{'ENTITY': 'infected'}, {'ENTITY': 'Covid-19'}, {'ENTITY': 'asymptomatic'}]
# 28
# 	[BASE]: coronavirus hydroxychloroquine, what evidence is there for the value of hydroxychloroquine in treating Covid-19?
# 	[NLTK low + stop]: coronavirus hydroxychloroquine, evidence value hydroxychloroquine treating covid-19 ?
# 	[NLTK low + stop + punct]: coronavirus hydroxychloroquine, evidence value hydroxychloroquine treating covid-19
# 	[NLTK low + stop + punct + lemma]: coronavirus hydroxychloroquine, evidence value hydroxychloroquine treat covid-19
# 	[CUSTOM STOPWORDS]: coronavirus hydroxychloroquine, evidence value hydroxychloroquine treat covid-19
# 	[NER]: [{'ENTITY': 'evidence'}, {'ENTITY': 'hydroxychloroquine'}, {'ENTITY': 'treating'}, {'ENTITY': 'Covid-19'}]
# 29
# 	[BASE]: coronavirus drug repurposing, which SARS-CoV-2 proteins-human proteins interactions indicate potential for drug targets. Are there approved drugs that can be repurposed based on this information?
# 	[NLTK low + stop]: coronavirus drug repurposing, sars-cov-2 proteins-human proteins interactions indicate potential drug targets . approved drugs repurposed based information ?
# 	[NLTK low + stop + punct]: coronavirus drug repurposing, sars-cov-2 proteins-human proteins interactions indicate potential drug targets approved drugs repurposed based information
# 	[NLTK low + stop + punct + lemma]: coronavirus drug repurposing, sars-cov-2 proteins-human protein interaction indicate potential drug target approve drug repurposed base information
# 	[CUSTOM STOPWORDS]: coronavirus drug repurposing, sars-cov-2 proteins-human protein interaction indicate potential drug target approve drug repurposed base information
# 	[NER]: [{'ENTITY': 'SARS-CoV-2'}, {'ENTITY': 'proteins-human proteins'}, {'ENTITY': 'interactions'}, {'ENTITY': 'potential'}, {'ENTITY': 'drug targets'}, {'ENTITY': 'drugs'}, {'ENTITY': 'repurposed'}, {'ENTITY': 'information'}]
# 30
# 	[BASE]: coronavirus remdesivir, is remdesivir an effective treatment for COVID-19
# 	[NLTK low + stop]: coronavirus remdesivir, remdesivir effective treatment covid-19
# 	[NLTK low + stop + punct]: coronavirus remdesivir, remdesivir effective treatment covid-19
# 	[NLTK low + stop + punct + lemma]: coronavirus remdesivir, remdesivir effective treatment covid-19
# 	[CUSTOM STOPWORDS]: coronavirus remdesivir, remdesivir effective treatment covid-19
# 	[NER]: [{'ENTITY': 'remdesivir'}, {'ENTITY': 'effective'}, {'ENTITY': 'treatment'}, {'ENTITY': 'COVID-19'}]
# 31
# 	[BASE]: difference between coronavirus and flu, How does the coronavirus differ from seasonal flu?
# 	[NLTK low + stop]: difference coronavirus flu, coronavirus differ seasonal flu ?
# 	[NLTK low + stop + punct]: difference coronavirus flu, coronavirus differ seasonal flu
# 	[NLTK low + stop + punct + lemma]: difference coronavirus flu, coronavirus differ seasonal flu
# 	[CUSTOM STOPWORDS]: difference coronavirus flu, coronavirus differ seasonal flu
# 	[NER]: [{'ENTITY': 'coronavirus'}, {'ENTITY': 'seasonal flu'}]
# 32
# 	[BASE]: coronavirus subtypes, Does SARS-CoV-2 have any subtypes, and if so what are they?
# 	[NLTK low + stop]: coronavirus subtypes, sars-cov-2 subtypes , ?
# 	[NLTK low + stop + punct]: coronavirus subtypes, sars-cov-2 subtypes
# 	[NLTK low + stop + punct + lemma]: coronavirus subtypes, sars-cov-2 subtypes
# 	[CUSTOM STOPWORDS]: coronavirus subtypes, sars-cov-2 subtypes
# 	[NER]: [{'ENTITY': 'SARS-CoV-2'}, {'ENTITY': 'subtypes'}]
# 33
# 	[BASE]: coronavirus vaccine candidates, What vaccine candidates are being tested for Covid-19?
# 	[NLTK low + stop]: coronavirus vaccine candidates, vaccine candidates tested covid-19 ?
# 	[NLTK low + stop + punct]: coronavirus vaccine candidates, vaccine candidates tested covid-19
# 	[NLTK low + stop + punct + lemma]: coronavirus vaccine candidate, vaccine candidate test covid-19
# 	[CUSTOM STOPWORDS]: coronavirus vaccine candidate, vaccine candidate test covid-19
# 	[NER]: [{'ENTITY': 'vaccine'}, {'ENTITY': 'candidates'}, {'ENTITY': 'tested'}, {'ENTITY': 'Covid-19'}]
# 34
# 	[BASE]: coronavirus recovery, What are the longer-term complications of those who recover from COVID-19?
# 	[NLTK low + stop]: coronavirus recovery, longer-term complications recover covid-19 ?
# 	[NLTK low + stop + punct]: coronavirus recovery, longer-term complications recover covid-19
# 	[NLTK low + stop + punct + lemma]: coronavirus recovery, longer-term complication recover covid-19
# 	[CUSTOM STOPWORDS]: coronavirus recovery, longer-term complication recover covid-19
# 	[NER]: [{'ENTITY': 'longer-term'}, {'ENTITY': 'complications'}, {'ENTITY': 'COVID-19'}]
# 35
# 	[BASE]: coronavirus public datasets, What new public datasets are available related to COVID-19?
# 	[NLTK low + stop]: coronavirus public datasets, new public datasets available related covid-19 ?
# 	[NLTK low + stop + punct]: coronavirus public datasets, new public datasets available related covid-19
# 	[NLTK low + stop + punct + lemma]: coronavirus public datasets, new public datasets available related covid-19
# 	[CUSTOM STOPWORDS]: coronavirus public datasets, new public datasets available related covid-19
# 	[NER]: [{'ENTITY': 'public datasets'}, {'ENTITY': 'COVID-19'}]
# 36
# 	[BASE]: SARS-CoV-2 spike structure, What is the protein structure of the SARS-CoV-2 spike?
# 	[NLTK low + stop]: sars-cov-2 spike structure, protein structure sars-cov-2 spike ?
# 	[NLTK low + stop + punct]: sars-cov-2 spike structure, protein structure sars-cov-2 spike
# 	[NLTK low + stop + punct + lemma]: sars-cov-2 spike structure, protein structure sars-cov-2 spike
# 	[CUSTOM STOPWORDS]: sars-cov-2 spike structure, protein structure sars-cov-2 spike
# 	[NER]: [{'ENTITY': 'protein structure'}, {'ENTITY': 'SARS-CoV-2'}, {'ENTITY': 'spike'}]
# 37
# 	[BASE]: SARS-CoV-2 phylogenetic analysis, What is the result of phylogenetic analysis of SARS-CoV-2 genome sequence?
# 	[NLTK low + stop]: sars-cov-2 phylogenetic analysis, result phylogenetic analysis sars-cov-2 genome sequence ?
# 	[NLTK low + stop + punct]: sars-cov-2 phylogenetic analysis, result phylogenetic analysis sars-cov-2 genome sequence
# 	[NLTK low + stop + punct + lemma]: sars-cov-2 phylogenetic analysis, result phylogenetic analysis sars-cov-2 genome sequence
# 	[CUSTOM STOPWORDS]: sars-cov-2 phylogenetic analysis, result phylogenetic analysis sars-cov-2 genome sequence
# 	[NER]: [{'ENTITY': 'result'}, {'ENTITY': 'phylogenetic analysis'}, {'ENTITY': 'SARS-CoV-2'}, {'ENTITY': 'genome sequence'}]
# 38
# 	[BASE]: COVID inflammatory response, What is the mechanism of inflammatory response and pathogenesis of COVID-19 cases?
# 	[NLTK low + stop]: covid inflammatory response, mechanism inflammatory response pathogenesis covid-19 cases ?
# 	[NLTK low + stop + punct]: covid inflammatory response, mechanism inflammatory response pathogenesis covid-19 cases
# 	[NLTK low + stop + punct + lemma]: covid inflammatory response, mechanism inflammatory response pathogenesis covid-19 case
# 	[CUSTOM STOPWORDS]: covid inflammatory response, mechanism inflammatory response pathogenesis covid-19 case
# 	[NER]: [{'ENTITY': 'mechanism'}, {'ENTITY': 'inflammatory response'}, {'ENTITY': 'pathogenesis'}, {'ENTITY': 'COVID-19'}, {'ENTITY': 'cases'}]
# 39
# 	[BASE]: COVID-19 cytokine storm, What is the mechanism of cytokine storm syndrome on the COVID-19?
# 	[NLTK low + stop]: covid-19 cytokine storm, mechanism cytokine storm syndrome covid-19 ?
# 	[NLTK low + stop + punct]: covid-19 cytokine storm, mechanism cytokine storm syndrome covid-19
# 	[NLTK low + stop + punct + lemma]: covid-19 cytokine storm, mechanism cytokine storm syndrome covid-19
# 	[CUSTOM STOPWORDS]: covid-19 cytokine storm, mechanism cytokine storm syndrome covid-19
# 	[NER]: [{'ENTITY': 'mechanism'}, {'ENTITY': 'cytokine storm syndrome'}, {'ENTITY': 'COVID-19'}]
# 40
# 	[BASE]: coronavirus mutations, What are the observed mutations in the SARS-CoV-2 genome and how often do the mutations occur?
# 	[NLTK low + stop]: coronavirus mutations, observed mutations sars-cov-2 genome often mutations occur ?
# 	[NLTK low + stop + punct]: coronavirus mutations, observed mutations sars-cov-2 genome often mutations occur
# 	[NLTK low + stop + punct + lemma]: coronavirus mutation, observed mutation sars-cov-2 genome often mutation occur
# 	[CUSTOM STOPWORDS]: coronavirus mutation, observed mutation sars-cov-2 genome mutation occur
# 	[NER]: [{'ENTITY': 'observed'}, {'ENTITY': 'mutations'}, {'ENTITY': 'SARS-CoV-2'}, {'ENTITY': 'genome'}, {'ENTITY': 'mutations'}]

# %% [markdown]
# Looks like combination of `[NLTK low + stop + punct + lemma]` retains the context for the query compared to `CUSTOM_STOPWORDS` as seen in Topic #15 it removes `outside` from the query which affects the context of the query.

# %% [markdown]
# ## Cleaning `query+question`

# %%
def clean_text(text):
    return ' '.join(tk.tokenize(text))
tk = Tokenizer('l-s-pt-lm')
query_df['cleaned_query'] = query_df['query+question'].progress_apply(clean_text)
query_df.head()
# Out:
# 100%|██████████| 40/40 [00:00<00:00, 725.33it/s]
#                                             query  \
# topic-id
# 1                              coronavirus origin
# 2         coronavirus response to weather changes
# 3                            coronavirus immunity
# 4          how do people die from the coronavirus
# 5                       animal models of COVID-19
#
#                                                    question  \
# topic-id
# 1                            what is the origin of COVID-19
# 2         how does the coronavirus respond to changes in...
# 3         will SARS-CoV2 infected people develop immunit...
# 4                          what causes death from Covid-19?
# 5         what drugs have been active against SARS-CoV o...
#
#                                              query+question  \
# topic-id
# 1         coronavirus origin what is the origin of COVID-19
# 2         coronavirus response to weather changes how do...
# 3         coronavirus immunity will SARS-CoV2 infected p...
# 4         how do people die from the coronavirus what ca...
# 5         animal models of COVID-19 what drugs have been...
#
#                                               cleaned_query
# topic-id
# 1                        coronavirus origin origin covid-19
# 2         coronavirus response weather change coronaviru...
# 3         coronavirus immunity sars-cov2 infected people...
# 4               people die coronavirus cause death covid-19
# 5         animal model covid-19 drug active sars-cov sar...

# %% [markdown]
# ## Connect to Elasticsearch Index

# %%
import json
import time
import os
from elasticsearch import Elasticsearch

INDEX_NAME = 'abstract'
with open("elastic.json") as elastic_file:
    ELASTIC_SETTINGS = json.loads(elastic_file.read().strip())
es_client = Elasticsearch(
    cloud_id=ELASTIC_SETTINGS["cloud_id"],
    http_auth=(ELASTIC_SETTINGS["user"], ELASTIC_SETTINGS["password"]),
)
print(f'Is ES client connected ? - {es_client.ping()}')
# Out:
# Is ES client connected ? - True

# %%
def search_on_abstract(query, qid, run_name, es_client, top_k=10, verbose=False):
    """ Searches the query and finds the best matches using elasticsearch."""
    # 1. create trec-covid template
    template = "{} Q0 {} {} {:.6f} {}\n"
    # 2. create ES search query
    search = {
        "size": top_k, 
        "query": {"match": {"abstract": query}},
        "_source": {"includes": ["cord_uid", "title"]}
    }
    response = es_client.search(
        index=INDEX_NAME,
        body=json.dumps(search)
    )
    ranked_lists = []
    for rank, hit in enumerate(response["hits"]["hits"]):
        cord_uid = hit["_source"]["cord_uid"]
        score = hit["_score"]
        title = hit["_source"]["title"]
        ranked_lists.append(template.format(qid, cord_uid, rank+1, score, run_name))
        if verbose:
            print("\tcord_id: {}".format(cord_uid))
            print("\ttitle: {}".format(title))
            print("\tscore: {}".format(score))
            print()
    return ranked_lists

def write_results(out_fpath, query_df, query_txt_col, es_client, run_name, top_k=1000):
    """Writes ranked results from elastic search results to txt file."""
    with open(out_fpath, 'w', encoding='utf-8') as writer:
        for idx, row in query_df.iterrows():
            qid = idx
            query = row[query_txt_col]
            ranked_lists = search_on_abstract(query, qid, run_name, es_client, top_k=top_k)
            writer.writelines(ranked_lists)
    print(f"Wrote file @ {out_fpath}\n")

# %%
# %%time
run_name = 'elasticsearch_baseline_abstract_cleaned_query'
query_txt_col = 'cleaned_query'
out_fpath = Path('../data/output') / f'{run_name}.txt'
write_results(out_fpath, query_df, query_txt_col, es_client, run_name)
# Out:
# Wrote file @ ../data/output/elasticsearch_baseline_abstract_cleaned_query.txt
#
# CPU times: user 258 ms, sys: 6.7 ms, total: 265 ms
# Wall time: 24.2 s

# %%
run_name = "elasticsearch_baseline_abstract_cleaned_query"
path_to_qrel_file = "../data/qrels/qrels-covid_d3_j0.5-3.txt"
path_to_result_file = f"../data/output/{run_name}.txt"
output_result_path = f"../data/results/{run_name}_trec_eval.txt"
os.system("trec_eval -c -m all_trec {} {} > {}".format(path_to_qrel_file, path_to_result_file, output_result_path))
with open(output_result_path, encoding='utf-8') as f:
    print(f.read())
# Out:
# runid                 	all	elasticsearch_baseline_abstract_cleaned_query
# num_q                 	all	40
# num_ret               	all	40000
# num_rel               	all	10001
# num_rel_ret           	all	3996
# map                   	all	0.1607
# gm_map                	all	0.1107
# Rprec                 	all	0.2514
# bpref                 	all	0.3462
# recip_rank            	all	0.7767
# iprec_at_recall_0.00  	all	0.8260
# iprec_at_recall_0.10  	all	0.4528
# iprec_at_recall_0.20  	all	0.3348
# iprec_at_recall_0.30  	all	0.2322
# iprec_at_recall_0.40  	all	0.1438
# iprec_at_recall_0.50  	all	0.0801
# iprec_at_recall_0.60  	all	0.0374
# iprec_at_recall_0.70  	all	0.0096
# iprec_at_recall_0.80  	all	0.0000
# iprec_at_recall_0.90  	all	0.0000
# iprec_at_recall_1.00  	all	0.0000
# P_5                   	all	0.6000
# P_10                  	all	0.5775
# P_15                  	all	0.5467
# P_20                  	all	0.5262
# P_30                  	all	0.4933
# P_100                 	all	0.3472
# P_200                 	all	0.2583
# P_500                 	all	0.1567
# P_1000                	all	0.0999
# recall_5              	all	0.0159
# recall_10             	all	0.0302
# recall_15             	all	0.0413
# recall_20             	all	0.0532
# recall_30             	all	0.0735
# recall_100            	all	0.1676
# recall_200            	all	0.2376
# recall_500            	all	0.3386
# recall_1000           	all	0.4199
# infAP                 	all	0.1607
# gm_bpref              	all	0.2888
# Rprec_mult_0.20       	all	0.4507
# Rprec_mult_0.40       	all	0.3594
# Rprec_mult_0.60       	all	0.3134
# Rprec_mult_0.80       	all	0.2770
# Rprec_mult_1.00       	all	0.2514
# Rprec_mult_1.20       	all	0.2265
# Rprec_mult_1.40       	all	0.2068
# Rprec_mult_1.60       	all	0.1930
# Rprec_mult_1.80       	all	0.1784
# Rprec_mult_2.00       	all	0.1660
# utility               	all	-800.2000
# 11pt_avg              	all	0.1924
# binG                  	all	0.0946
# G                     	all	0.0820
# ndcg                  	all	0.4051
# ndcg_rel              	all	0.3997
# Rndcg                 	all	0.3423
# ndcg_cut_5            	all	0.5611
# ndcg_cut_10           	all	0.5356
# ndcg_cut_15           	all	0.5067
# ndcg_cut_20           	all	0.4869
# ndcg_cut_30           	all	0.4585
# ndcg_cut_100          	all	0.3547
# ndcg_cut_200          	all	0.3272
# ndcg_cut_500          	all	0.3580
# ndcg_cut_1000         	all	0.4051
# map_cut_5             	all	0.0140
# map_cut_10            	all	0.0246
# map_cut_15            	all	0.0327
# map_cut_20            	all	0.0401
# map_cut_30            	all	0.0529
# map_cut_100           	all	0.0993
# map_cut_200           	all	0.1252
# map_cut_500           	all	0.1494
# map_cut_1000          	all	0.1607
# relative_P_5          	all	0.6000
# relative_P_10         	all	0.5775
# relative_P_15         	all	0.5467
# relative_P_20         	all	0.5262
# relative_P_30         	all	0.4933
# relative_P_100        	all	0.3515
# relative_P_200        	all	0.3037
# relative_P_500        	all	0.3398
# relative_P_1000       	all	0.4199
# success_1             	all	0.6500
# success_5             	all	0.9000
# success_10            	all	0.9750
# set_P                 	all	0.0999
# set_relative_P        	all	0.4199
# set_recall            	all	0.4199
# set_map               	all	0.0453
# set_F                 	all	0.1543
# num_nonrel_judged_ret 	all	3745

# %% [markdown]
# - `MAP` - 0.1607
# - `NDCG@10` - 0.5356
# - `P@5` - 0.6000
# - `R@1000` - 0.4199
#
# Results are pretty close so with or without normalizing query by removing stopwords or case folding it. Next, let's do query expansion using word embeddings trained on dataset.

# %% [markdown]
# ## Query Expansion

# %%
from gensim.models import KeyedVectors
from IPython.display import display_html
cbow_vectors = KeyedVectors.load("../data/embeddings/cbow_word2vec.bin")

# %%
cbow_vectors.wv.most_similar(positive='quarantine', topn=10)
# Out:
# [('distancing', 0.8528013229370117),
#  ('strict', 0.8384310007095337),
#  ('containment', 0.833786129951477),
#  ('quarantining', 0.8291466236114502),
#  ('quarantined', 0.8246265649795532),
#  ('tracing', 0.8222387433052063),
#  ('self-quarantine', 0.8033556938171387),
#  ('lock-down', 0.7976255416870117),
#  ('self-isolation', 0.7923141717910767),
#  ('pre-symptomatic', 0.7876335382461548)]

# %%
def expand_terms(text):
    ents = [e.text for e in nlp(text).ents]
    terms = set()
    for ent in ents:
        words = ent.split(' ')
        try:
            results = cbow_vectors.wv.most_similar(positive=words, topn=5)
            results = [result[0] for result in results]
            terms.update(results)
        except:
            pass
    return ' '.join(terms)

# %%
topic_id = 12
query_question = query_df.loc[topic_id]['query']
print(query_question)
expand_terms(query_question)
# Out:
# coronavirus quarantine
# 'syndrome-related (sars)-cov-2 corona coronavirus-2 2019'

# %%
query_df['expanded_query'] = query_df['query+question'] + ' ' + query_df['query'].progress_apply(expand_terms)
query_df.head()
# Out:
# 100%|██████████| 40/40 [00:00<00:00, 63.01it/s]
#                                             query  \
# topic-id
# 1                              coronavirus origin
# 2         coronavirus response to weather changes
# 3                            coronavirus immunity
# 4          how do people die from the coronavirus
# 5                       animal models of COVID-19
#
#                                                    question  \
# topic-id
# 1                            what is the origin of COVID-19
# 2         how does the coronavirus respond to changes in...
# 3         will SARS-CoV2 infected people develop immunit...
# 4                          what causes death from Covid-19?
# 5         what drugs have been active against SARS-CoV o...
#
#                                              query+question  \
# topic-id
# 1         coronavirus origin what is the origin of COVID-19
# 2         coronavirus response to weather changes how do...
# 3         coronavirus immunity will SARS-CoV2 infected p...
# 4         how do people die from the coronavirus what ca...
# 5         animal models of COVID-19 what drugs have been...
#
#                                               cleaned_query  \
# topic-id
# 1                        coronavirus origin origin covid-19
# 2         coronavirus response weather change coronaviru...
# 3         coronavirus immunity sars-cov2 infected people...
# 4               people die coronavirus cause death covid-19
# 5         animal model covid-19 drug active sars-cov sar...
#
#                                              expanded_query
# topic-id
# 1         coronavirus origin what is the origin of COVID...
# 2         coronavirus response to weather changes how do...
# 3         coronavirus immunity will SARS-CoV2 infected p...
# 4         how do people die from the coronavirus what ca...
# 5         animal models of COVID-19 what drugs have been...

# %%
# %%time
run_name = 'elasticsearch_baseline_abstract_expanded_query'
query_txt_col = 'expanded_query'
out_fpath = Path('../data/output') / f'{run_name}.txt'
write_results(out_fpath, query_df, query_txt_col, es_client, run_name)
# Out:
# Wrote file @ ../data/output/elasticsearch_baseline_abstract_expanded_query.txt
#
# CPU times: user 281 ms, sys: 7.81 ms, total: 289 ms
# Wall time: 24.6 s

# %%
run_name = "elasticsearch_baseline_abstract_expanded_query"
path_to_qrel_file = "../data/qrels/qrels-covid_d3_j0.5-3.txt"
path_to_result_file = f"../data/output/{run_name}.txt"
output_result_path = f"../data/results/{run_name}_trec_eval.txt"
os.system("trec_eval -c -m all_trec {} {} > {}".format(path_to_qrel_file, path_to_result_file, output_result_path))
with open(output_result_path, encoding='utf-8') as f:
    print(f.read())
# Out:
# runid                 	all	elasticsearch_baseline_abstract_expanded_query
# num_q                 	all	40
# num_ret               	all	40000
# num_rel               	all	10001
# num_rel_ret           	all	3147
# map                   	all	0.1123
# gm_map                	all	0.0601
# Rprec                 	all	0.1861
# bpref                 	all	0.2941
# recip_rank            	all	0.6378
# iprec_at_recall_0.00  	all	0.6922
# iprec_at_recall_0.10  	all	0.3455
# iprec_at_recall_0.20  	all	0.2187
# iprec_at_recall_0.30  	all	0.1343
# iprec_at_recall_0.40  	all	0.0817
# iprec_at_recall_0.50  	all	0.0445
# iprec_at_recall_0.60  	all	0.0177
# iprec_at_recall_0.70  	all	0.0078
# iprec_at_recall_0.80  	all	0.0036
# iprec_at_recall_0.90  	all	0.0000
# iprec_at_recall_1.00  	all	0.0000
# P_5                   	all	0.5250
# P_10                  	all	0.5175
# P_15                  	all	0.4667
# P_20                  	all	0.4463
# P_30                  	all	0.3967
# P_100                 	all	0.2602
# P_200                 	all	0.1891
# P_500                 	all	0.1185
# P_1000                	all	0.0787
# recall_5              	all	0.0141
# recall_10             	all	0.0267
# recall_15             	all	0.0365
# recall_20             	all	0.0465
# recall_30             	all	0.0604
# recall_100            	all	0.1261
# recall_200            	all	0.1792
# recall_500            	all	0.2652
# recall_1000           	all	0.3430
# infAP                 	all	0.1123
# gm_bpref              	all	0.2426
# Rprec_mult_0.20       	all	0.3622
# Rprec_mult_0.40       	all	0.2737
# Rprec_mult_0.60       	all	0.2372
# Rprec_mult_0.80       	all	0.2068
# Rprec_mult_1.00       	all	0.1861
# Rprec_mult_1.20       	all	0.1702
# Rprec_mult_1.40       	all	0.1559
# Rprec_mult_1.60       	all	0.1441
# Rprec_mult_1.80       	all	0.1343
# Rprec_mult_2.00       	all	0.1269
# utility               	all	-842.6500
# 11pt_avg              	all	0.1405
# binG                  	all	0.0722
# G                     	all	0.0647
# ndcg                  	all	0.3253
# ndcg_rel              	all	0.3209
# Rndcg                 	all	0.2657
# ndcg_cut_5            	all	0.4698
# ndcg_cut_10           	all	0.4557
# ndcg_cut_15           	all	0.4237
# ndcg_cut_20           	all	0.4095
# ndcg_cut_30           	all	0.3717
# ndcg_cut_100          	all	0.2694
# ndcg_cut_200          	all	0.2472
# ndcg_cut_500          	all	0.2801
# ndcg_cut_1000         	all	0.3253
# map_cut_5             	all	0.0124
# map_cut_10            	all	0.0212
# map_cut_15            	all	0.0278
# map_cut_20            	all	0.0344
# map_cut_30            	all	0.0426
# map_cut_100           	all	0.0722
# map_cut_200           	all	0.0878
# map_cut_500           	all	0.1038
# map_cut_1000          	all	0.1123
# relative_P_5          	all	0.5250
# relative_P_10         	all	0.5175
# relative_P_15         	all	0.4667
# relative_P_20         	all	0.4463
# relative_P_30         	all	0.3967
# relative_P_100        	all	0.2625
# relative_P_200        	all	0.2244
# relative_P_500        	all	0.2662
# relative_P_1000       	all	0.3430
# success_1             	all	0.5250
# success_5             	all	0.7000
# success_10            	all	0.9000
# set_P                 	all	0.0787
# set_relative_P        	all	0.3430
# set_recall            	all	0.3430
# set_map               	all	0.0311
# set_F                 	all	0.1225
# num_nonrel_judged_ret 	all	2606

# %% [markdown]
# In this case using query expansion hurt the results, even though word embeddings were pretty close, so it's not always the case query expansion helps.
#
# **Key Metrics**,
#
# - `MAP` - 0.1123
# - `NDCG@10` - 0.4557
# - `P@5` - 0.5250
# - `R@1000` - 0.3430
